# %%
from src.streamlit.mods import histogram_color as hc 
hc.compute(show=True, name_id=0, opacity=0.9)

# %%
import pandas as pd

# %%
from sklearn.feature_selection import SelectFromModel, SelectPercentile, RFE, f_classif, SelectKBest
from sklearn.decomposition import PCA
from sklearn.manifold import LocallyLinearEmbedding, TSNE,

# %%
import tensorflow as tf

# %%
tf.keras.preprocessing.image.ImageDataGenerator().flow_from_dataframe()
