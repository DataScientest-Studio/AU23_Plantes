# %%
import src.features as lf
import src.models as lm
from src.models.stages import *

#### Directories
lm.models.RECORD_DIR='./models/records'
lm.models.FIGURE_DIR='./reports/figures'

PATH = './dataset/'
#### Data building
data_wrapper = lf.data_builder.create_dataset_from_directory(PATH)

# %%
#### Campaign init
models = [
  # stage1.Stage1MobileNetv3,
  # stage1.Stage1ResNetv2,
  # stage2.Stage2MobileNetv3,
  # stage2.Stage2ResNetv2,
  # stage3.Stage3MobileNetv3,
  # stage3.Stage3ResNetv2,
  # stage4.Stage4MobileNetv3,
  # stage4.Stage4ResNetv2,
  # stage5.Stage5MobileNetv3,
  # stage5.Stage5ResNetv2,
  stage6.Stage6MobileNetv3
  ]
campaign= lm.campaign.Campaign(campaign_id='test', data_wrapper=data_wrapper, models=models)

#### train
#### models will be serialized in RECORD_DIR (launch only once by campaign)

#campaign.train_all()


#### evaluate
#### models will be loaded and results saved in FIGURE_DIR/campaign_id

#campaign.evaluate_and_build_reports()

# %%
campaign.evaluate_and_build_reports()
# Out:
# Found 4382 validated image filenames belonging to 12 classes.
# Found 597 validated image filenames belonging to 12 classes.
# Found 554 validated image filenames belonging to 12 classes.
# >>> Stage-6_MobileNetv3 –– Loading
# ++++++model++++++history1++++++history2+++
# >>> Stage-6_MobileNetv3 –– Evaluation
# 18/18 [==============================] - 14s 702ms/step
# >>> Stage-6_MobileNetv3 –– Classification Report
# Saving figure to ./reports/figures/test/Stage-6_MobileNetv3_classification_report.png
# >>> Stage-6_MobileNetv3 –– Display training history graphs
# Saving figure to ./reports/figures/test/Stage-6_MobileNetv3_history_graph.png
# >>> Stage-6_MobileNetv3 –– Display confusion matrix
# Saving figure to ./reports/figures/test/Stage-6_MobileNetv3_confusion_matrix.png
# >>> Stage-6_MobileNetv3 –– Display training data samples
# Saving figure to ./reports/figures/test/Stage-6_MobileNetv3_sample_graphs.png
# >>> Stage-6_MobileNetv3 –– Display training data samples
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Saving figure to ./reports/figures/test/Stage-6_MobileNetv3_sample_graphs_gradcam_guidedGradcam.png
# >>> Stage-6_MobileNetv3 –– Display training data samples
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Conv_1
# Saving figure to ./reports/figures/test/Stage-6_MobileNetv3_sample_graphs_segmented_gradcam_guidedGradcam.png
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\amib\OneDrive\Documents\Drive\OneDrive\Bureau\vision-ai\plants\AU23_Plantes\main.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/amib/OneDrive/Documents/Drive/OneDrive/Bureau/vision-ai/plants/AU23_Plantes/main.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> campaign.evaluate_and_build_reports()
#
# File c:\Users\amib\OneDrive\Documents\Drive\OneDrive\Bureau\vision-ai\plants\AU23_Plantes\src\models\campaign.py:48, in Campaign.evaluate_and_build_reports(self, gradcam)
#      46     m.save_evaluation_reports(gradcam)
#      47     self.active_models.append(m)
# ---> 48 self.compare_models_confusions(save=True)
#      49 self.compare_models_performances(save=True)
#
# File c:\Users\amib\OneDrive\Documents\Drive\OneDrive\Bureau\vision-ai\plants\AU23_Plantes\src\models\campaign.py:55, in Campaign.compare_models_confusions(self, save)
#      54 def compare_models_confusions(self, save= False):
# ---> 55     lv.graphs.compare_models_confusions(self.active_models, save=save, fig_dir=lm.models.FIGURE_DIR)
#
# File c:\Users\amib\OneDrive\Documents\Drive\OneDrive\Bureau\vision-ai\plants\AU23_Plantes\src\visualization\graphs.py:203, in compare_models_confusions(active_models, save, fig_dir)
#     201 fig = px.bar(confusions_df, y='count', x='actual', animation_frame='model', color='confusion')
#     202 fig.update_layout(yaxis=dict(range=[0, max + 2]))
# --> 203 fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 3000
#     204 fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 800
#     205 fig.update_layout(title=f"class confusion evolution between models –– {campaign_id} campaign")
#
# IndexError: tuple index out of range
